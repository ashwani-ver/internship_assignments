# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('amz_com-ecommerce_sample.csv',encoding= 'unicode_escape')
df1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                             product_name  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1.dtypes
# Out:
# uniq_id                         object
# crawl_timestamp                 object
# product_url                     object
# product_name_on_flipkart        object
# product_category_tree           object
# pid                             object
# retail_price_on_flipkart         int64
# discounted_price_on_flipkart     int64
# image                           object
# is_FK_Advantage_product           bool
# description                     object
# product_rating                  object
# overall_rating                  object
# brand                           object
# product_specifications          object
# matched_product                 object
# dtype: object

# %%
#renaming columns to differentiate between flipkart and amazon
df1.rename(columns = {'product_name' :'product_name_on_flipkart','retail_price':'retail_price_on_flipkart','discounted_price':'discounted_price_on_flipkart'},inplace = True)

# %%
df1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                 product_name_on_flipkart  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df2 = pd.read_csv('flipkart_com-ecommerce_sample.csv')
df2.head(10)
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# 5  c2a17313954882c1dba461863e98adf2  2016-03-25 22:59:23 +0000
# 6  ce5a6818f7707e2cb61fdcdbba61f5ad  2016-03-25 22:59:23 +0000
# 7  8542703ca9e6ebdf6d742638dfb1f2ca  2016-03-25 22:59:23 +0000
# 8  29c8d290caa451f97b1c32df64477a2c  2016-03-25 22:59:23 +0000
# 9  4044c0ac52c1ee4b28777417651faf42  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
#renaming columns in  amazon data
df2.rename(columns = {'product_name' :'product_name_on_amazon','retail_price':'retail_price_on_amazon','discounted_price':'discounted_price_on_amazon'},inplace = True)

# %%
df2.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   product_name_on_amazon  \
# 0    Alisha Solid Women's Cycling Shorts
# 1    FabHomeDecor Fabric Double Sofa Bed
# 2                             AW Bellies
# 3    Alisha Solid Women's Cycling Shorts
# 4  Sicons All Purpose Arnica Dog Shampoo
#
# ...

# %%
df1.shape
# Out:
# (20000, 15)

# %%
df2.shape
# Out:
# (20000, 15)

# %%
#converting all strings of flipkart to lower case to avoid upper case and lower case error in alphabets
df1["product_name_on_flipkart"] = df1["product_name_on_flipkart"].str.lower()
df1.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                 product_name_on_flipkart  \
# 0    alisha solid women's cycling shorts
# 1    fabhomedecor fabric double sofa bed
# 2                             aw bellies
# 3    alisha solid women's cycling shorts
# 4  sicons all purpose arnica dog shampoo
#
# ...

# %%
#converting all strings of flipkart to lower case to avoid upper case and lower case error in alphabets

df2["product_name_on_amazon"] = df2["product_name_on_amazon"].str.lower()
df2.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   product_name_on_amazon  \
# 0    alisha solid women's cycling shorts
# 1    fabhomedecor fabric double sofa bed
# 2                             aw bellies
# 3    alisha solid women's cycling shorts
# 4  sicons all purpose arnica dog shampoo
#
# ...

# %%
#using np.where function to match the product names and assigning matched columns to '1' amd ummatched columns to  '0'.
df1['matched_product'] = np.where(df1['product_name_on_flipkart'] == df2['product_name_on_amazon'],'1','0')

# %%
df1.shape
# Out:
# (20000, 16)

# %%
#check the matched products
df1[df1['matched_product'] == '1']
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
#checking unmatched products
unmatched_1 = df1[df1['matched_product'] == '0']
unmatched_1.head(85)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 28     171e0bcea390c17fd70e3ffa6c2cd187  2016-01-03 20:56:50 +0000
# 883    874bd2156910ddcd36d8c6813d4c4544  2016-01-06 18:20:45 +0000
# 1304   d5740b5581dc89a1daff65f8e6208847  2016-03-17 12:56:51 +0000
# 1575   22296bfc1c79d9dc88eabbd01220ef0c  2016-01-04 00:20:04 +0000
# 3575   324fba9c3fc304f69b32c50f0caa94e7  2015-12-01 12:40:44 +0000
# ...                                 ...                        ...
# 19838  1c926040eada0086bac29e3e670ccd8e  2015-12-01 10:15:43 +0000
# 19839  f28e8effde7da54527f385799736b42b  2015-12-01 10:15:43 +0000
# 19841  d29da980534c374c5d045d0529380de0  2015-12-01 10:15:43 +0000
# 19844  f8a828f40fa105fa030497b9b5ba9467  2015-12-01 10:15:43 +0000
# 19845  26120ced973bbf25b672cc3ba1a749b7  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 28     http://www.flipkart.com/fdt-women-s-leggings/p...
# ...

# %%
#matched product in flipkart
true_flipkart = df1[df1['matched_product'] == '1']
true_flipkart
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
#unmatched product in amazon
unmatched_2 = df2[df2['matched_product'] == '0']
unmatched_2.head(85)
# Out:
#                                 uniq_id            crawl_timestamp  \
# 28     171e0bcea390c17fd70e3ffa6c2cd187  2016-01-03 20:56:50 +0000
# 883    874bd2156910ddcd36d8c6813d4c4544  2016-01-06 18:20:45 +0000
# 1304   d5740b5581dc89a1daff65f8e6208847  2016-03-17 12:56:51 +0000
# 1575   22296bfc1c79d9dc88eabbd01220ef0c  2016-01-04 00:20:04 +0000
# 3575   324fba9c3fc304f69b32c50f0caa94e7  2015-12-01 12:40:44 +0000
# ...                                 ...                        ...
# 19838  1c926040eada0086bac29e3e670ccd8e  2015-12-01 10:15:43 +0000
# 19839  f28e8effde7da54527f385799736b42b  2015-12-01 10:15:43 +0000
# 19841  d29da980534c374c5d045d0529380de0  2015-12-01 10:15:43 +0000
# 19844  f8a828f40fa105fa030497b9b5ba9467  2015-12-01 10:15:43 +0000
# 19845  26120ced973bbf25b672cc3ba1a749b7  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 28     http://www.flipkart.com/fdt-women-s-leggings/p...
# ...

# %%
true_flipkart = pd.DataFrame(true)
true_flipkart

# %%
df3 = true_flipkart[['product_name_on_flipkart','retail_price_on_flipkart','discounted_price_on_flipkart']]
df3
# Out:
#                       product_name_on_flipkart  retail_price_on_flipkart  \
# 0          alisha solid women's cycling shorts                       982
# 1          fabhomedecor fabric double sofa bed                     32143
# 2                                   aw bellies                       991
# 3          alisha solid women's cycling shorts                       694
# 4        sicons all purpose arnica dog shampoo                       208
# ...                                        ...                       ...
# 19995           walldesign small vinyl sticker                      1498
# 19996  wallmantra large vinyl stickers sticker                      1415
# 19997  elite collection medium acrylic sticker                      1284
# 19998  elite collection medium acrylic sticker                      1492
# 19999  elite collection medium acrylic sticker                      1484
#
#        discounted_price_on_flipkart
# 0                               438
# ...

# %%
df2['matched_product'] = np.where(df1['product_name_on_flipkart'] == df2['product_name_on_amazon'],'1','0')

# %%
df2.head()
# Out:
#                             uniq_id            crawl_timestamp  \
# 0  c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1  7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2  f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3  0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4  bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
#
#                                          product_url  \
# 0  http://www.flipkart.com/alisha-solid-women-s-c...
# 1  http://www.flipkart.com/fabhomedecor-fabric-do...
# 2  http://www.flipkart.com/aw-bellies/p/itmeh4grg...
# 3  http://www.flipkart.com/alisha-solid-women-s-c...
# 4  http://www.flipkart.com/sicons-all-purpose-arn...
#
#                   product_name_on_amazon  \
# 0    alisha solid women's cycling shorts
# 1    fabhomedecor fabric double sofa bed
# 2                             aw bellies
# 3    alisha solid women's cycling shorts
# 4  sicons all purpose arnica dog shampoo
#
# ...

# %%
#matched product from amazon
true_amazon = df2[df2['matched_product'] == '1']
true_amazon.shape
# Out:
# (19851, 16)

# %%
true_amazon = pd.DataFrame(true_amazon)
true_amazon
# Out:
#                                 uniq_id            crawl_timestamp  \
# 0      c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 1      7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
# 2      f449ec65dcbc041b6ae5e6a32717d01b  2016-03-25 22:59:23 +0000
# 3      0973b37acd0c664e3de26e97e5571454  2016-03-25 22:59:23 +0000
# 4      bc940ea42ee6bef5ac7cea3fb5cfbee7  2016-03-25 22:59:23 +0000
# ...                                 ...                        ...
# 19995  7179d2f6c4ad50a17d014ca1d2815156  2015-12-01 10:15:43 +0000
# 19996  71ac419198359d37b8fe5e3fffdfee09  2015-12-01 10:15:43 +0000
# 19997  93e9d343837400ce0d7980874ece471c  2015-12-01 10:15:43 +0000
# 19998  669e79b8fa5d9ae020841c0c97d5e935  2015-12-01 10:15:43 +0000
# 19999  cb4fa87a874f715fff567f7b7b3be79c  2015-12-01 10:15:43 +0000
#
#                                              product_url  \
# 0      http://www.flipkart.com/alisha-solid-women-s-c...
# ...

# %%
#extracting the required columns
df4 = true_amazon[['product_name_on_amazon','retail_price_on_amazon','discounted_price_on_amazon']]
df4.head()
# Out:
#                   product_name_on_amazon  retail_price_on_amazon  \
# 0    alisha solid women's cycling shorts                   999.0
# 1    fabhomedecor fabric double sofa bed                 32157.0
# 2                             aw bellies                   999.0
# 3    alisha solid women's cycling shorts                   699.0
# 4  sicons all purpose arnica dog shampoo                   220.0
#
#    discounted_price_on_amazon
# 0                       379.0
# 1                     22646.0
# 2                       499.0
# 3                       267.0
# 4                       210.0

# %%
#adding both dataframes
matched_product = pd.concat([df3,df4], axis = 'columns')

# %%
matched_product
# Out:
#                       product_name_on_flipkart  retail_price_on_flipkart  \
# 0          alisha solid women's cycling shorts                       982
# 1          fabhomedecor fabric double sofa bed                     32143
# 2                                   aw bellies                       991
# 3          alisha solid women's cycling shorts                       694
# 4        sicons all purpose arnica dog shampoo                       208
# ...                                        ...                       ...
# 19995           walldesign small vinyl sticker                      1498
# 19996  wallmantra large vinyl stickers sticker                      1415
# 19997  elite collection medium acrylic sticker                      1284
# 19998  elite collection medium acrylic sticker                      1492
# 19999  elite collection medium acrylic sticker                      1484
#
#        discounted_price_on_flipkart                   product_name_on_amazon  \
# ...

# %%
matched_product.to_csv('matched_products.csv', index = False)

# %%
#still some data is left which is partially matching.
product_name_on_flipkart = []
retail_price_on_flipkart = []
discounted_price_on_flipkart = []
product_name_on_amazon = []
retail_price_on_amazon= []
discounted_price_on_amazon = []
#partial_match = []

# %%
#partially matching products
for i in range(150):
    if(str(unmatched_1.product_name_on_flipkart)[i] in str(unmatched_2.product_name_on_amazon)[i]):
        product_name_on_flipkart.append(unmatched_1.product_name_on_flipkart.iloc[i])
        retail_price_on_flipkart.append(unmatched_1.retail_price_on_flipkart.iloc[i])
        discounted_price_on_flipkart.append(unmatched_1.discounted_price_on_flipkart.iloc[i])
        product_name_on_amazon.append(unmatched_2.product_name_on_amazon.iloc[i])
        retail_price_on_amazon.append(unmatched_2.retail_price_on_amazon.iloc[i])
        discounted_price_on_amazon.append(unmatched_2.discounted_price_on_amazon.iloc[i])
        print("yes",i)
        
    else:
        print('no')
# Out:
# yes 0
# yes 1
# yes 2
# yes 3
# yes 4
# yes 5
# yes 6
# yes 7
# yes 8
# yes 9
# yes 10
# yes 11
# yes 12
# yes 13
# yes 14
# yes 15
# yes 16
# yes 17
# yes 18
# yes 19
# yes 20
# yes 21
# yes 22
# yes 23
# yes 24
# yes 25
# yes 26
# yes 27
# yes 28
# yes 29
# yes 30
# yes 31
# no
# no
# no
# yes 35
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 45
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 55
# no
# yes 57
# yes 58
# yes 59
# yes 60
# yes 61
# yes 62
# yes 63
# yes 64
# yes 65
# yes 66
# yes 67
# yes 68
# yes 69
# yes 70
# yes 71
# yes 72
# yes 73
# yes 74
# yes 75
# yes 76
# yes 77
# yes 78
# yes 79
# yes 80
# yes 81
# yes 82
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 114
# yes 115
# yes 116
# yes 117
# yes 118
# yes 119
# yes 120
# yes 121
# yes 122
# yes 123
# yes 124
# yes 125
# yes 126
# yes 127
# yes 128
# yes 129
# yes 130
# yes 131
# yes 132
# ...

# %%
#cross checking by changing the columns
for j in range(150):
    if(str(unmatched_2.product_name_on_amazon)[j] in str(unmatched_1.product_name_on_flipkart)[j]):
        
        print("yes",j)
    else:
        print('no')
# Out:
# yes 0
# yes 1
# yes 2
# yes 3
# yes 4
# yes 5
# yes 6
# yes 7
# yes 8
# yes 9
# yes 10
# yes 11
# yes 12
# yes 13
# yes 14
# yes 15
# yes 16
# yes 17
# yes 18
# yes 19
# yes 20
# yes 21
# yes 22
# yes 23
# yes 24
# yes 25
# yes 26
# yes 27
# yes 28
# yes 29
# yes 30
# yes 31
# no
# no
# no
# yes 35
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 45
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 55
# no
# yes 57
# yes 58
# yes 59
# yes 60
# yes 61
# yes 62
# yes 63
# yes 64
# yes 65
# yes 66
# yes 67
# yes 68
# yes 69
# yes 70
# yes 71
# yes 72
# yes 73
# yes 74
# yes 75
# yes 76
# yes 77
# yes 78
# yes 79
# yes 80
# yes 81
# yes 82
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# no
# yes 114
# yes 115
# yes 116
# yes 117
# yes 118
# yes 119
# yes 120
# yes 121
# yes 122
# yes 123
# yes 124
# yes 125
# yes 126
# yes 127
# yes 128
# yes 129
# yes 130
# yes 131
# yes 132
# ...

# %%
unmatched_1.product_name_on_flipkart.iloc[0]
# Out:
# "fdt women's leggings pants"

# %%
new = pd.DataFrame(
    { 
        'product_name_on_flipkart': product_name_on_flipkart,
        'retail_price_on_flipkart':retail_price_on_flipkart,
        'discounted_price_on_flipkart':discounted_price_on_flipkart,
        'product_name_on_amazon':product_name_on_amazon,
        'retail_price_on_amazon':retail_price_on_amazon,
        'discounted_price_on_amazon':discounted_price_on_amazon
    })
new
#columns = ['product_name_on_flipkart','retail_price_on_flipkart','discounted_price_on_flipkart','product_name_on_amazon','retail_price_on_amazon','discounted_price_on_amazon'])
#new
# Out:
#                              product_name_on_flipkart  \
# 0                          fdt women's leggings pants
# 1   kuberbox sortilã¨ge pearl gold diamond, pearl ...
# 2   kartique handmade wooden box for women jewel o...
# 3   beyoutiful copper repoussï¿½ï¿½ - man with dho...
# 4   prithish the only thing better than having you...
# ..                                                ...
# 91                         walldesign s vinyl sticker
# 92                 elite collection m acrylic sticker
# 93                 elite collection m acrylic sticker
# 94                         walldesign s vinyl sticker
# 95                         walldesign s vinyl sticker
#
#     retail_price_on_flipkart  discounted_price_on_flipkart  \
# 0                        698                           362
# 1                      26051                         31102
# 2                        314                           325
# 3                       1692                          1253
# ...

# %%
final_data = pd.concat([new,matched_product], axis = 0)
final_data
# Out:
#                                 product_name_on_flipkart  \
# 0                             fdt women's leggings pants
# 1      kuberbox sortilã¨ge pearl gold diamond, pearl ...
# 2      kartique handmade wooden box for women jewel o...
# 3      beyoutiful copper repoussï¿½ï¿½ - man with dho...
# 4      prithish the only thing better than having you...
# ...                                                  ...
# 19995                     walldesign small vinyl sticker
# 19996            wallmantra large vinyl stickers sticker
# 19997            elite collection medium acrylic sticker
# 19998            elite collection medium acrylic sticker
# 19999            elite collection medium acrylic sticker
#
#        retail_price_on_flipkart  discounted_price_on_flipkart  \
# 0                           698                           362
# 1                         26051                         31102
# 2                           314                           325
# ...

# %%
final_data.to_csv('similar_products.csv')
